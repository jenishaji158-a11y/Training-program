# %% [markdown]
# <a href="https://colab.research.google.com/github/jenishaji158-a11y/Training-program/blob/main/Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
n=int(input("enter number of monkeys"))
k=int(input("enter k"))
j=int(input("enter j"))
m=int(input("enter m"))
p=int(input("enter p"))
if k<0 or j<0:
      print("invalid input")

noofmonkeys=m//k+p//j


n=n-noofmonkeys
if m%k!=0 or p%j!=0:
      n=n-1
print(n)
# Out:
# enter number of monkeys20
# enter k2
# enter j3
# enter m12
# enter p12
# 10

# %%
print("Using Temp")
a,b=10,5
temp=a
a=b
b=temp
print(a,b)
print("Using ,")
a,b=10,5
a,b=b,a
print(a,b)
print("Using + and -")
a,b=10,5
a=a+b
b=a-b
a=a-b
print(a,b)
print("Using ^")
a,b=10,5
a=a^b
b=a^b
a=a^b
print(a,b)
# Out:
# Using Temp
# 5 10
# Using ,
# 5 10
# Using + and -
# 5 10
# Using ^
# 5 10

# %%
n=int(input("Enter jar capacity:"))
k=int(input("Enter min candies:"))
t=n
i='y'
ts=0
while i !='n':
  x=int(input("Enter candies to sold:"))
  if x>n:
    print("Invalid input")
  else:
    n=n-x
    ts=ts+x
    print("Sold:",x)
    if n<=k:
      n=t
    print("Available candies:",n)
    print("Total sold",ts)
# Out:
# Sold: 3
# Available candies: 3
# Total sold 3
# Sold: 3
# Available candies: 3
# Total sold 6
# Sold: 3
# Available candies: 3
# Total sold 9
# Sold: 3
# Available candies: 3
# Total sold 12

# %%
a=int(input("Enter list size:"))
list=[]
for i in range(a):
  b=int(input("Enter the elements in the list"))
  list.append(b)
print("LIST:",list)
# Out:
# Enter list size:5
# Enter the elements in the list12
# Enter the elements in the list23
# Enter the elements in the list21
# Enter the elements in the list24
# Enter the elements in the list25
# LIST: [12, 23, 21, 24, 25]

# %%
n=int(input("enter the number of elements"))
a=[]
for i in range(n):
  m=int(input("enter the element"))
  a.append(m)
  print(a)
print("the largest element is",max(a))
# Out:
# enter the number of elements4
# enter the element23
# [23]
# enter the element34
# [23, 34]
# enter the element45
# [23, 34, 45]
# enter the element56
# [23, 34, 45, 56]
# the largest element is 56

# %%
n=int(input("enter the number of elements"))
a=[]
for i in range(n):
  m=int(input("enter the element"))
  a.append(m)
  print(a)
print("the smallest element is",min(a))
# Out:
# enter the number of elements4
# enter the element22
# [22]
# enter the element34
# [22, 34]
# enter the element2
# [22, 34, 2]
# enter the element4
# [22, 34, 2, 4]
# the smallest element is 2

# %%
arr=[]
n=int(input("enter a number"))
for i in range(n):
    arr.append(int(input("enter a number")))
print(arr)
print("the sum is",sum(arr))
# Out:
# enter a number4
# enter a number55
# enter a number45
# enter a number65
# enter a number33
# [55, 45, 65, 33]
# the sum is 198

# %%
a=int(input("Enter an array size:"))
arr=[]
for i in range(a):
  el=int(input("Enter array elements:"))
  arr.append(el)
print("Reversed array is:",arr[::-1])
# Out:
# Enter an array size:4
# Enter array elements:12
# Enter array elements:6
# Enter array elements:8
# Enter array elements:4
# Reversed array is: [4, 8, 6, 12]

# %%
a=int(input("Enter the list size:"))
list=[]
for i in range(a):
  b=int(input("enter the elements:"))
  list.append(b)
k=int(input("Enter an element to be searched:"))
if k in list:
    print("Element exist!")
else:
    print("Element not exist!")
# Out:
# Enter the list size:3
# enter the elements:8
# enter the elements:10
# enter the elements:20
# Enter an element to be searched:15
# Element not exist!

# %%
a=int(input("Enter the list size:"))
list=[]
for i in range(a):
  b=int(input("enter the elements:"))
  list.append(b)
b=int(input("enter the element to be checked:"))
count=list.count(b)
print("occurance of ",b,"is:",count)
# Out:
# Enter the list size:3
# enter the elements:5
# enter the elements:6
# enter the elements:7
# enter the element to be checked:6
# occurance of  6 is: 1

# %%
a=int(input("Enter the list size:"))
list=[]
for i in range(a):
  b=int(input("enter the elements:"))
  list.append(b)
list.sort()
print("Second largest element is:",list[-2])
# Out:
# Enter the list size:3
# enter the elements:4
# enter the elements:6
# enter the elements:8
# Second largest element is: 6

# %%
a=int(input("Enter the list size:"))
list=[]
for i in range(a):
  b=int(input("enter the elements:"))
  list.append(b)
list.sort()
print("Sorted array is:",list)
# Out:
# Enter the list size:3
# enter the elements:12
# enter the elements:41
# enter the elements:8
# Sorted array is: [8, 12, 41]

# %%
n=int(input("Enter the no. of elements: "))
a=[]
for i in range(n):
  a.append(int(input("Enter the element: ")))
print("List=",a)
n=[]
for i in a:
  if i not in n:
    n.append(i)
print("Updated list=",n)
# Out:
# Enter the no. of elements: 4
# Enter the element: 6
# Enter the element: 6
# Enter the element: 1
# Enter the element: 8
# List= [6, 6, 1, 8]
# Updated list= [6, 1, 8]

# %%
i=map(int,(input("Enter elements:").split()))
print(list(i))
# Out:
# Enter elements:2 4 5 6
# [2, 4, 5, 6]

# %%
a =[5,10,15,20,25]
print(a[1:2])
print(a[:2])
print(a[3:])
print(a[::-4])
print(a[1::-4])
# Out:
# [10]
# [5, 10]
# [20, 25]
# [25, 5]
# [10]
